# %% [markdown]
# ##### Set Plotly Credentials

# %%
import plotly

# %%
plotly.tools.set_credentials_file(username='jamesdoone', api_key='zwZ2xOcldcyr8HNCOxmI')

# %% [markdown]
# ##### won't push your work to the cloud

# %%
import plotly.offline as pyo

# %% [markdown]
# ##### Allows us to create the Data and Figure Objects

# %%
from plotly.graph_objs import *

# %% [markdown]
# ##### Pushes your charts to the cloud

# %%
import plotly.plotly as py

# %% [markdown]
# ##### Richard's website

# %%
import pandas as pd

# %%
pd.read_csv("http://richard-muir.com/data/public/csv/BoEBaseRate.csv")
# Out:
#        VALUE        DATE
# 0      11.50  02/01/1975
# 1      11.50  03/01/1975
# 2      11.50  06/01/1975
# 3      11.50  07/01/1975
# 4      11.50  08/01/1975
# 5      11.50  09/01/1975
# 6      11.50  10/01/1975
# 7      11.50  13/01/1975
# 8      11.50  14/01/1975
# 9      11.50  15/01/1975
# 10     11.50  16/01/1975
# 11     11.50  17/01/1975
# 12     11.25  20/01/1975
# 13     11.25  21/01/1975
# 14     11.25  22/01/1975
# 15     11.25  23/01/1975
# 16     11.25  24/01/1975
# 17     11.00  27/01/1975
# 18     11.00  28/01/1975
# 19     11.00  29/01/1975
# 20     11.00  30/01/1975
# 21     11.00  31/01/1975
# 22     11.00  03/02/1975
# 23     11.00  04/02/1975
# 24     11.00  05/02/1975
# 25     11.00  06/02/1975
# 26     11.00  07/02/1975
# 27     10.75  10/02/1975
# 28     10.75  11/02/1975
# 29     10.75  12/02/1975
# ...      ...         ...
# 10456   0.50  12/05/2016
# 10457   0.50  13/05/2016
# 10458   0.50  16/05/2016
# 10459   0.50  17/05/2016
# 10460   0.50  18/05/2016
# ...

# %% [markdown]
# ##### Matplotlib upload

# %%
import plotly.plotly as py
py.sign_in('jamesdoone', 'zwZ2xOcldcyr8HNCOxmI')


fig = plt.gcf()

plot_url = py.plot_mpl(fig)
